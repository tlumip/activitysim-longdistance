# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path

# %%
data_dir = Path(
    "/Users/jeffnewman/Library/CloudStorage/OneDrive-SharedLibraries-CambridgeSystematics"
    "/PROJ 210048 - Ohio DOT Modeling Support - ASim-LongDist/ValidationData/Files/LDT_Survey"
)

# %%
tour_patterns = pd.read_csv(data_dir/"tour_patterns.csv")

# %%
tour_patterns
# Out:
#         hh_id   per_id   tour   oneday  purpose  pattern   type   anchor_taz  \
# 0     5016239        2      1        0        H      hov    0.0       9087.0
# 1     5016239        1      1        0        H      hov    0.0       9087.0
# 2     4039961        2      1        0        O     homv    0.0      31169.0
# 3     4039961        4      1        0        O     homv    0.0      31169.0
# 4     4039961        1      1        1        O      hok    0.0      31169.0
# ...       ...      ...    ...      ...      ...      ...    ...          ...
# 8117  5001037        1      6        0        O      vov    0.0      77022.0
# 8118  4014319        2      1        0        O      hov    0.0      83053.0
# 8119  4014319        4      1        0        O      hov    0.0      83053.0
# 8120  4014319        1      1        0        O      hov    0.0      83053.0
# 8121  4014319        3      1        0        O      hov    NaN          NaN
#
# ...
